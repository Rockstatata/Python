# %%
import numpy as np

list1 = [1,3,9,27,0]
length = len(list1)
sum = 0
for i in list1:
    sum+=i
avg = sum/length
print(f"The length of the list is {length}")
print(f"The mean of the list is {avg}")
# Out:
# The length of the list is 5
# The mean of the list is 8.0

# %%
import numpy as np

image1 = np.array([
    [1,2,0],
    [1,20,2],
    [4,2,1]
])

image2 = np.array([
    [0,1,0],
    [1,29,1],
    [2,1,1]
])

image3 = np.array([
    [1,1,0],
    [0,31,1],
    [2,1,0]
])

stack = (image1+image2+image3)/3
print(stack)
# Out:
# [[ 0.66666667  1.33333333  0.        ]
#  [ 0.66666667 26.66666667  1.33333333]
#  [ 2.66666667  1.33333333  0.66666667]]

# %%
# CSV -> COMMA SEPARATED VALUE FILES

import pandas as pd

data = pd.read_csv("ngc_1068.csv",encoding="ISO-8859-1")

data
# Out:
#      4835  5135  4835.1  4835.2  4835.3  5041  4741  4741.1  5041.1  4891  \
# 0    4835  4835    4535    4835    5435  5041  4741    4741    5041  4591
# 1    4816  4741    4741    5041    5041  4835  5135    4685    4685  4760
# 2    4516  4741    4741    5041    5041  5135  5435    4985    4385  4760
# 3    4816  4591    4591    4741    4441  5135  4535    4985    4685  4460
# 4    4816  4591    4591    4441    4741  4835  4835    4985    5285  4760
# ..    ...   ...     ...     ...     ...   ...   ...     ...     ...   ...
# 347  5164  4639    4639    4789    5089  4882  4882    5332    4732  4957
# 348  5164  4939    4939    4789    5089  5182  5182    5032    4432  4957
# 349  5164  5014    5314    5164    4564  4620  4920    4920    5220  4770
# 350  5164  5014    5314    4864    4864  5220  4920    4920    5220  5070
# 351  5164  4864    4564    4864    5164  4920  4920    4920    5220  5070
#
#      ...  4895.7  5195.3  4895.8  5195.4  4895.9  4895.10  4970.18  4970.19  \
# 0    ...    4595    4895    4595    4895    4895     4895     4670     4670
# 1    ...    4895    4895    4651    4951    4951     4651     4801     5101
# 2    ...    5195    5195    4651    4951    4951     4651     4501     4801
# 3    ...    5345    5345    5101    5401    4951     4651     4501     4801
# 4    ...    4745    4745    4801    4501    4951     5251     4801     5101
# ..   ...     ...     ...     ...     ...     ...      ...      ...      ...
# 347  ...    4429    4729    5048    5048    4748     4748     4748     4748
# 348  ...    5029    4729    5048    5048    4748     4748     4748     4748
# 349  ...    5029    4729    4973    4673    4523     4523     4598     4898
# 350  ...    5029    4729    4973    4673    5123     5123     4598     4898
# 351  ...    4579    5179    4973    4673    4973     4373     4598     4598
#
#      4970.20  4670.7
# 0       4970    4670
# 1       5251    4951
# 2       5251    4951
# 3       4801    4801
# 4       4801    4801
# ..       ...     ...
# 347     4748    4748
# 348     5048    4448
# 349     4598    4898
# 350     4298    4598
# 351     4598    4598
#
# [352 rows x 353 columns]

# %%
import matplotlib.pyplot as plt
plt.matshow(data)
plt.show()
